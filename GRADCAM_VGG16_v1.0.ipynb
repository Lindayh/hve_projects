# %%
# https://keras.io/examples/vision/grad_cam/#setup
# https://dmitry.ai/t/topic/50/2
# Check Lambda Cloud

# %%
import os

# os.environ["KERAS_BACKEND"] = "tensorflow"

import numpy as np
import tensorflow as tf
import keras

# Display
from IPython.display import Image, display
import matplotlib as mpl
import matplotlib.pyplot as plt

from keras import backend as K
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import pandas as pd
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.applications.vgg16 import decode_predictions
import numpy as np
import seaborn as sns
import cv2
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.optimizers import Adam 
from tensorflow.keras.models import load_model
import tensorflow.keras

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Conv2D, Flatten
from tensorflow.keras import regularizers
from IPython.display import Image

import warnings 
warnings.filterwarnings('ignore')
# Out:
# 2024-10-30 09:13:49.006079: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-30 09:13:49.017394: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-30 09:13:49.020712: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-30 09:13:49.030244: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-30 09:13:49.716350: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
print(tf.__version__)
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# 2.17.0
# Num GPUs Available:  1
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1730276031.056543    2125 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1730276031.089018    2125 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1730276031.089254    2125 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %%
# img_path = r'images_dl/pic.png'
img_path = r'images_dl/aiimg02.png'

# %%
VGG16_base_model = tf.keras.applications.VGG16(
    include_top = False, 
    weights = 'imagenet', 
    input_shape = (32,32, 3),
    # pooling = 'max'
)
VGG16_base_model.trainable = False

# Create a new model on top of the MobileNet base
inputs = tf.keras.Input(shape = (32,32, 3))
x = VGG16_base_model(inputs, training = False)

x = BatchNormalization(axis = -1, momentum = 0.99, epsilon = 0.001)(x)
x = Dense(256, 
          kernel_regularizer = regularizers.l2(0.01), 
          activity_regularizer = regularizers.l1(0.01), 
          bias_regularizer = regularizers.l1(0.01),
          activation = 'relu')(x)
x = Dropout(rate = .4, seed = 512)(x)       
x = Dense(64, activation = 'relu')(x)

outputs = Dense(1, activation = 'sigmoid')(x)
VGG16_model = tf.keras.Model(inputs, outputs)

# Compile the Transfer Learning model
VGG16_model.compile(
    optimizer = 'adam',
    loss = tf.keras.losses.BinaryCrossentropy(),
    metrics = ['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
)

VGG16_model.load_weights("models/kaggle/VGG16_model.weights.h5")
# Out:
# I0000 00:00:1730276031.128354    2125 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1730276031.128614    2125 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1730276031.128785    2125 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1730276031.183399    2125 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1730276031.183609    2125 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1730276031.183786    2125 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-30 09:13:51.183913: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4139 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1060 6GB, pci bus id: 0000:06:00.0, compute capability: 6.1

# %%
# Load img
img = image.load_img(img_path, target_size=(32, 32))
# plt.imshow(img)

# %%
img = image.img_to_array(img)
img = preprocess_input(img, data_format=None)
img = img/255.0

img = np.expand_dims(img, axis=0)
img.shape, type(img)
# Out:
# ((1, 32, 32, 3), numpy.ndarray)

# %%
img_pred = VGG16_model.predict(img)
print(img_pred)
print('FAKE') if img_pred.argmax() == 0 else print('REAL')
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1730276032.170207    2188 service.cc:146] XLA service 0x7569200050e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1730276032.170224    2188 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce GTX 1060 6GB, Compute Capability 6.1
# 2024-10-30 09:13:52.176835: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-10-30 09:13:52.235339: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# [[[[0.99592906]]]]
# FAKE
# I0000 00:00:1730276033.247056    2188 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.

# %%
def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions


    grad_model = keras.models.Model(
        model.inputs, [model.get_layer(last_conv_layer_name).output, model.output]
    )

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)  
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]


    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # # This is a vector where each entry is the mean intensity of the gradient
    # # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

# MobileNet
# last_conv_layer_name = 'expanded_conv_10_project'   
# heatmap = make_gradcam_heatmap(img, MobileNet_model, last_conv_layer_name, pred_index=0)

# VGG
last_conv_layer_name = 'block1_conv2'
heatmap = make_gradcam_heatmap(img, VGG16_base_model, last_conv_layer_name, pred_index=0)


plt.matshow(heatmap)
# Out:
# W0000 00:00:1730276033.301209    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.312824    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.314124    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.315125    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.316106    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.317122    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.318242    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.319292    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.321661    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.322650    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.323620    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.324615    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.325597    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.375963    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.377065    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.379241    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.380264    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.381270    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.382273    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.383321    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.384316    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.385499    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.387903    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.388927    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.389953    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.391561    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.392614    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.393773    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.395820    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.396852    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.398214    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.399276    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.410750    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.412633    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.413612    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.414585    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.415577    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.416583    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.417604    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.418796    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.421198    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.422218    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.423234    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.424272    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.425305    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.426349    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.427788    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.429293    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.430326    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.431384    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.432420    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.433879    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.435448    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.444171    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.445779    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.446765    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.447815    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.448850    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.449906    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.450998    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.452249    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.455053    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.456997    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.458010    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.459053    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.460168    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.461641    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.462742    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.463811    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.464894    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.466025    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.467988    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.469856    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.477438    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.478969    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.479950    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.480999    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.482035    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.483082    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.484174    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.485343    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.488381    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.490008    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.491029    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.492090    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.493215    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.494417    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.495950    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.497053    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.498139    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.499224    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.502154    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.509330    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.510356    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.512589    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.513686    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.514811    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.515939    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.517169    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.518422    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.521549    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.523297    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.524469    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.525661    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.526889    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.529368    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.530544    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.531745    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.532974    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.534294    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.537753    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.549315    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.550418    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.551608    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.554110    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.555330    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.556492    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.557694    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.558870    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.559998    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.562442    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.563687    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.564899    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.566115    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.567292    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.568631    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.571479    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.572899    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.574153    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.583955    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.590722    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.591975    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.593224    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.595726    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.597064    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.598397    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.599813    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.601305    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.604039    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.605565    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.607089    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.608584    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.610115    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.612749    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.614176    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.616022    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.617537    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.637529    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.644674    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.646044    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.647298    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.648574    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.649895    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.651250    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.654079    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.655503    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.656838    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.658281    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.660217    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.662602    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.663990    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.665840    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.667358    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.685598    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.719711    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.721261    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.722554    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.723805    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.725391    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.731425    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.732770    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.734159    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.754807    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.756915    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.757976    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.760089    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.762636    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.763850    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.765015    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.766192    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.767420    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.782600    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.785814    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.788441    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.789697    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.791287    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.797481    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.798833    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.800215    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.803126    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.805316    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.806402    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.807956    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.809140    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.810444    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.812434    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.813634    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.814858    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.826383    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.828568    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.829738    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.830834    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.832099    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.835143    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.836439    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.837806    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.840474    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.841500    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.842523    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.844500    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.846060    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.847139    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.848186    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.849242    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.850337    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.858282    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.859315    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.860637    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.861779    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.862757    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.863809    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.864963    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.866604    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.869361    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.870383    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.871381    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.872506    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.873525    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.874540    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.875540    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.876542    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.877544    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.878593    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.884928    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.885945    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.887141    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.888293    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.889266    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.890255    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.891326    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.892818    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.903481    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.907501    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.908538    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.909588    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.910971    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.912478    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.913518    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.914567    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.915539    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.916516    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.917519    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.918579    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.921003    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.921986    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.926449    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.927555    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.928642    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.929698    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.930680    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.931672    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.932789    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.935760    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.936780    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.937809    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.938831    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.939821    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.940818    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.941854    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.942886    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.943884    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.944896    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.945918    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.947303    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.948312    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.952504    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.953485    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.954565    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.955617    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.956598    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.957580    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.958641    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.960892    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.962266    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.963233    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.964186    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.965146    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.966124    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.967091    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.968179    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.969292    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.971668    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.972664    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.976345    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.977421    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.978423    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.979438    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.980911    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.981935    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.983134    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.984725    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.987181    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.988170    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.989189    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.990198    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.991205    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.992204    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.993214    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.995503    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.996528    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.997559    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276033.998669    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276034.002509    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276034.004332    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276034.005305    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276034.006278    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276034.007296    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276034.008326    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276034.009380    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276034.010580    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276034.013607    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276034.014599    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276034.015579    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276034.016571    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276034.017577    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276034.018695    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276034.021171    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1730276034.022196    2125 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced

# %% [markdown]
# ##### Show heatmap on img

# %%
def save_and_display_gradcam(img_path, heatmap, cam_path="cam.jpg", alpha=0.4):
    # Load the original image
    img = keras.utils.load_img(img_path)
    img = keras.utils.img_to_array(img)

    # Rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)

    # Use jet colormap to colorize heatmap
    jet = mpl.colormaps["jet"]

    # Use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # Create an image with RGB colorized heatmap
    jet_heatmap = keras.utils.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = keras.utils.img_to_array(jet_heatmap)

    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = keras.utils.array_to_img(superimposed_img)

    # Save the superimposed image
    superimposed_img.save(cam_path)

    # Display Grad CAM
    display(Image(cam_path))


save_and_display_gradcam(img_path, heatmap)
